# %%
import pandas as pd

# %%
df = pd.read_csv("/content/superstore_sample.csv")

# %%
df.groupby("Region").sum()
# Out:
#            Row ID  Postal Code        Sales  Quantity  Discount       Profit
# Region
# Central  11685963    151786150  501239.8908      8780    558.34   39706.3625
# East     14073919     50171698  678781.2400     10618    414.00   91522.7800
# South     8213295     55875052  391721.9050      6209    238.55   46749.4303
# West     15971838    293739752  725457.8245     12266    350.20  108418.4489

# %%
df.groupby('Region').apply(lambda u: u["Profit"].min())
# Out:
# Region
# Central   -3701.8928
# East      -6599.9780
# South     -3839.9904
# West      -3399.9800
# dtype: float64

# %%
z = df.groupby('Region').size()
print(z)
z[z.values > 2000]
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# dtype: int64
# Region
# Central    2323
# East       2848
# West       3203
# dtype: int64

# %%
df.groupby(by=['Region'], as_index=False)['Profit'].sum()
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.loc[df["Ship Mode"] == "Second Class"]
# Out:
#       Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0          1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1          2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2          3  CA-2016-138688  6/12/2016   6/16/2016  Second Class    DV-13045
# 17        18  CA-2014-167164  5/13/2014   5/15/2014  Second Class    AG-10270
# 18        19  CA-2014-143336  8/27/2014    9/1/2014  Second Class    ZD-21925
# ...      ...             ...        ...         ...           ...         ...
# 9965    9966  CA-2016-146374  12/5/2016  12/10/2016  Second Class    HE-14800
# 9966    9967  CA-2016-146374  12/5/2016  12/10/2016  Second Class    HE-14800
# 9980    9981  US-2015-151435   9/6/2015    9/9/2015  Second Class    SW-20455
# 9989    9990  CA-2014-110422  1/21/2014   1/23/2014  Second Class    TB-21400
# 9993    9994  CA-2017-119914   5/4/2017    5/9/2017  Second Class    CC-12220
#
# ...

# %%
df[df["Ship Mode"] != ""]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 9989    9990
# 9990    9991
# 9991    9992
# 9992    9993
# 9993    9994
# Name: Row ID, Length: 9994, dtype: int64

# %%
df.iloc[1]
# Out:
# Row ID                                                           2
# Order ID                                            CA-2016-152156
# Order Date                                               11/8/2016
# Ship Date                                               11/11/2016
# Ship Mode                                             Second Class
# Customer ID                                               CG-12520
# Customer Name                                          Claire Gute
# Segment                                                   Consumer
# Country                                              United States
# City                                                     Henderson
# State                                                     Kentucky
# Postal Code                                                  42420
# Region                                                       South
# Product ID                                         FUR-CH-10000454
# ...

# %%
df.apply(lambda x: x["Sales"] * x["Quantity"], axis=1)
# Out:
# 0        523.9200
# 1       2195.8200
# 2         29.2400
# 3       4787.8875
# 4         44.7360
#           ...
# 9989      75.7440
# 9990     183.9200
# 9991     517.1520
# 9992     118.4000
# 9993     486.3200
# Length: 9994, dtype: float64

# %%
def function(x):
  return x["Sales"] * x["Quantity"]
df.apply(lambda x: function(x), axis=1)
# Out:
# 0        523.9200
# 1       2195.8200
# 2         29.2400
# 3       4787.8875
# 4         44.7360
#           ...
# 9989      75.7440
# 9990     183.9200
# 9991     517.1520
# 9992     118.4000
# 9993     486.3200
# Length: 9994, dtype: float64

# %%
df.loc[df["Category"] == "Furniture", "Category"] = "Orange"

# %%
df.iloc[1,1] = "TungLam"

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  Orange          Orange      Orange      Orange          Orange      Orange
# 1  Orange         TungLam      Orange      Orange          Orange      Orange
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  Orange          Orange      Orange      Orange          Orange      Orange
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0           Orange     Orange         Orange           Orange  ...
# 1           Orange     Orange         Orange           Orange  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3           Orange     Orange         Orange           Orange  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
def check(x):
  if x == "Orange":
    return True 
  return False
df["New column"] = df["Ship Mode"].apply(lambda x: check(x))

# %%
df["New column"]
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9989     True
# 9990     True
# 9991    False
# 9992    False
# 9993    False
# Name: New column, Length: 9994, dtype: bool

# %%
df.loc[:3, lambda x: ['Ship Date', 'Country']]
# Out:
#    Ship Date        Country
# 0     Orange         Orange
# 1     Orange         Orange
# 2  6/16/2016  United States
# 3     Orange         Orange
